# %%
# prompt: mount drive

from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/DIP
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/DIP

# %%
import os
import cv2
import random
from imgaug import augmenters as iaa

import imgaug as ia


def apply_random_augmentations(image):
    # Define a sequence of augmentations
    seq = iaa.Sequential([
        iaa.Fliplr(0.5),  # Horizontal flip with probability 0.5
        iaa.GaussianBlur(sigma=(0, 1.0)),  # Gaussian blur with sigma between 0 and 1.0
        iaa.AdditiveGaussianNoise(scale=(0, 0.05*255)),  # Gaussian noise
        iaa.ContrastNormalization((0.5, 2.0)),  # Contrast augmentation
        iaa.MultiplyBrightness((0.5, 1.5)),  # Multiply brightness augmentation
        iaa.PerspectiveTransform(scale=(0.01, 0.1))  # Perspective transform
    ], random_order=True)  # Randomize the order of augmentations

    # Apply augmentations to the image
    augmented_image = seq(image=image)

    return augmented_image

# %%
input_dir = '/content/drive/MyDrive/DIP/Dataset/Colors'
output_dir = '/content/drive/MyDrive/DIP/Dataset/Colors_aug'

# Ensure the output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

image_files = os.listdir(input_dir)
n_times = 2  # Adjust this based on how many times you want to augment each image
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_dir, image_file)
    image = cv2.imread(image_path)
    for i in range(n_times):
        augmented_image = apply_random_augmentations(image)
        output_file = os.path.splitext(image_file)[0] + f'_augmented_{i}.jpg'
        output_path = os.path.join(output_dir, output_file)
        cv2.imwrite(output_path, augmented_image)

        print(f"Augmented image saved: {output_path}")
# Out:
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9842_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9842_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98422_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98422_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6199_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6199_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61961_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61961_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61972_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61972_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6196_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6196_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6198_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6198_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0180_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0180_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6197_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6197_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61971_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61971_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61982_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61982_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0179_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0179_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61981_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61981_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98432_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98432_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9843_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9843_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9835_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9835_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61983_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61983_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98051_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98051_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98352_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98352_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98351_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98351_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9805_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9805_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98361_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98361_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98362_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98362_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9836_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9836_augmented_1.jpg

# %%
input_dir = '/content/drive/MyDrive/DIP/Dataset/Foreign'
output_dir = '/content/drive/MyDrive/DIP/Dataset/Foreign_aug'

# Ensure the output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

image_files = os.listdir(input_dir)
n_times = 5  # Adjust this based on how many times you want to augment each image
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_dir, image_file)
    image = cv2.imread(image_path)
    for i in range(n_times):
        augmented_image = apply_random_augmentations(image)
        output_file = os.path.splitext(image_file)[0] + f'_augmented_{i}.jpg'
        output_path = os.path.join(output_dir, output_file)
        cv2.imwrite(output_path, augmented_image)

        print(f"Augmented image saved: {output_path}")
# Out:
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_4.jpg

# %%
input_dir = '/content/drive/MyDrive/DIP/Dataset/Holes'
output_dir = '/content/drive/MyDrive/DIP/Dataset/Holes_aug'

# Ensure the output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

image_files = os.listdir(input_dir)
n_times = 2  # Adjust this based on how many times you want to augment each image
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_dir, image_file)
    image = cv2.imread(image_path)
    for i in range(n_times):
        augmented_image = apply_random_augmentations(image)
        output_file = os.path.splitext(image_file)[0] + f'_augmented_{i}.jpg'
        output_path = os.path.join(output_dir, output_file)
        cv2.imwrite(output_path, augmented_image)

        print(f"Augmented image saved: {output_path}")
# Out:
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9711_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9711_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9716_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9716_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9696_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9696_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9717_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9717_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0245_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0245_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0248_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0248_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0247_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0247_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0246_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0246_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9723_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9723_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9752_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9752_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9741_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9741_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9681_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9681_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9707_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9707_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9686_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9686_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9685_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9685_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9679_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9679_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138(1)_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138(1)_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0178_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0178_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0220_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0220_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115530_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115530_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0177_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0177_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9680_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9680_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0172_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0172_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0173_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0173_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115237_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115237_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115537_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115537_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115232_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115232_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115541_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115541_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115249_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115249_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0297_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0297_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9787_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9787_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/sdf_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/sdf_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9764_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9764_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9751_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9751_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9763_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9763_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9762_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9762_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9755_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9755_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9765_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9765_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9771_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9771_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0298_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0298_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0295_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0295_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0296_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0296_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6139_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6139_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6140_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6140_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_616f5_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_616f5_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9677_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9677_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6101_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6101_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6137_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6137_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6100_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6100_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0244_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0244_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9745_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9745_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9740_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9740_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0243_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0243_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0171_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0171_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0272_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0272_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6165_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6165_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115551_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115551_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6133_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6133_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0221_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0221_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0273_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0273_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115548_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115548_augmented_1.jpg

# %%
input_dir = '/content/drive/MyDrive/DIP/Dataset/Swing'
output_dir = '/content/drive/MyDrive/DIP/Dataset/Swing_aug'

# Ensure the output directory exists, if not, create it
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

image_files = os.listdir(input_dir)
n_times = 5  # Adjust this based on how many times you want to augment each image
for image_file in image_files:
    # Load the image
    image_path = os.path.join(input_dir, image_file)
    image = cv2.imread(image_path)
    for i in range(n_times):
        augmented_image = apply_random_augmentations(image)
        output_file = os.path.splitext(image_file)[0] + f'_augmented_{i}.jpg'
        output_path = os.path.join(output_dir, output_file)
        cv2.imwrite(output_path, augmented_image)

        print(f"Augmented image saved: {output_path}")
# Out:
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_4.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_0.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_1.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_2.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_3.jpg
# Augmented image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_4.jpg

# %%
import os
import cv2

def resize_images_in_directory(input_dir, output_size):
    # List all files in the input directory
    image_files = os.listdir(input_dir)

    # Iterate through each image file in the input directory
    for image_file in image_files:
        # Construct the full path of the image file
        image_path = os.path.join(input_dir, image_file)

        # Read the image
        image = cv2.imread(image_path)

        # Resize the image
        resized_image = cv2.resize(image, output_size)

        # Save the resized image with the same filename as the original image
        cv2.imwrite(image_path, resized_image)

        print(f"Resized image saved: {image_path}")

# Example usage:
output_size = (640, 640)  # Desired output size (width, height)
input_directory = '/content/drive/MyDrive/DIP/Dataset/Holes_aug'
resize_images_in_directory(input_directory, output_size)
input_directory = '/content/drive/MyDrive/DIP/Dataset/Swing_aug'
resize_images_in_directory(input_directory, output_size)
input_directory = '/content/drive/MyDrive/DIP/Dataset/Foreign_aug'
resize_images_in_directory(input_directory, output_size)
input_directory = '/content/drive/MyDrive/DIP/Dataset/Colors_aug'
resize_images_in_directory(input_directory, output_size)
# Out:
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9711_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9711_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9716_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9716_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9696_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9696_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9717_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9717_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0245_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0245_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0248_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0248_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0247_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0247_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0246_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0246_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9723_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9723_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9752_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9752_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9741_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9741_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9681_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9681_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9707_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9707_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9686_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9686_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9685_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9685_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9679_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9679_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138(1)_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138(1)_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0178_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0178_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0220_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0220_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115530_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115530_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0177_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0177_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9680_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9680_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0172_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0172_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0173_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0173_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115237_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115237_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115537_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115537_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115232_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115232_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115541_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115541_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115249_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115249_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0297_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0297_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9787_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9787_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/sdf_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/sdf_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9764_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9764_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9751_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9751_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9763_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9763_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9762_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9762_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9755_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9755_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9765_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9765_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9771_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9771_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0298_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0298_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0295_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0295_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0296_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0296_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6139_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6139_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6140_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6140_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_616f5_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_616f5_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9677_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9677_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6101_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6101_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6137_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6137_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6138_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6100_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6100_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0244_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0244_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9745_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9745_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9740_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_9740_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0243_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0243_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0171_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0171_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0272_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0272_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6165_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6165_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115551_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115551_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6133_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_6133_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0221_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0221_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0273_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_0273_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115548_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Holes_aug/IMG_20240508_115548_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6126_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0233_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0286_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0285_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0265_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0231_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0226_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0228_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0227_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0232_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9893_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9892_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9689_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9894_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6130_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6129_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_0287_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_9688_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Swing_aug/IMG_6127_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6193_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9792_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6189_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0277_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0223_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0274_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0275_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9837_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9840_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9838_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9839_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0303_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_6190_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0278_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0301_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0302_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9788_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_0276_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9889_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9888_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9890_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_2.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_3.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Foreign_aug/IMG_9891_augmented_4.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9842_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9842_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98422_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98422_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6199_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6199_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61961_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61961_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61972_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61972_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6196_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6196_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6198_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6198_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0180_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0180_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6197_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_6197_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61971_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61971_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61982_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61982_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0179_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_0179_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61981_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61981_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98432_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98432_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9843_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9843_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9835_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9835_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61983_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_61983_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98051_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98051_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98352_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98352_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98351_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98351_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9805_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9805_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98361_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98361_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98362_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_98362_augmented_1.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9836_augmented_0.jpg
# Resized image saved: /content/drive/MyDrive/DIP/Dataset/Colors_aug/IMG_9836_augmented_1.jpg
